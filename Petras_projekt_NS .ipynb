# %%
import pandas as pd # naimportovanie kniznice pandas na spracovanie udajov, vstup a vystup suboru CSV
import numpy as np # naimportovanie kniznice numby, pouziva sa pre pracu s polami, maticami...
import matplotlib.pyplot as plt # naimportovanie kniznice matplotlib.pyplot, pouziva na sa vizualizaciu dat

# %%
# pomocou kniznice pandas mozeme pracovat s classou dataframe
# do premennej 'dataset' sme si nacitali pomocou kniznice pandas vsetky data zo suboru 'weatherAus.csv'
dataset = pd.read_csv("weatherAUS.csv")

# pozrieme sa ako vyzera dataset s ktorym budeme pracovat
display(dataset.head(15)) # zobrazime si prvych 15 zaznamov z datasetu
display(dataset.tail(15)) # zobrazime si poslednych 15 zaznamov z datasetu
# Out:
#           Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1   2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2   2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3   2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4   2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5   2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6   2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7   2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8   2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9   2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 10  2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# 11  2008-12-12   Albury     15.9     21.7       2.2          NaN       NaN
# 12  2008-12-13   Albury     15.9     18.6      15.6          NaN       NaN
# 13  2008-12-14   Albury     12.6     21.0       3.6          NaN       NaN
# 14  2008-12-15   Albury      8.4     24.6       0.0          NaN       NaN
#
#    WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0            W           44.0          W  ...        71.0         22.0
# 1          WNW           44.0        NNW  ...        44.0         25.0
# 2          WSW           46.0          W  ...        38.0         30.0
# 3           NE           24.0         SE  ...        45.0         16.0
# 4            W           41.0        ENE  ...        82.0         33.0
# 5          WNW           56.0          W  ...        55.0         23.0
# 6            W           50.0         SW  ...        49.0         19.0
# 7            W           35.0        SSE  ...        48.0         19.0
# 8          NNW           80.0         SE  ...        42.0          9.0
# 9            W           28.0          S  ...        58.0         27.0
# 10           N           30.0        SSE  ...        48.0         22.0
# 11         NNE           31.0         NE  ...        89.0         91.0
# 12           W           61.0        NNW  ...        76.0         93.0
# 13          SW           44.0          W  ...        65.0         43.0
# 14         NaN            NaN          S  ...        57.0         32.0
#
#     Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0        1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1        1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2        1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3        1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4        1010.8       1006.0       7.0       8.0     17.8     29.7         No
# 5        1009.2       1005.4       NaN       NaN     20.6     28.9         No
# 6        1009.6       1008.2       1.0       NaN     18.1     24.6         No
# 7        1013.4       1010.1       NaN       NaN     16.3     25.5         No
# 8        1008.9       1003.6       NaN       NaN     18.3     30.2         No
# 9        1007.0       1005.7       NaN       NaN     20.1     28.2        Yes
# 10       1011.8       1008.7       NaN       NaN     20.4     28.8         No
# 11       1010.5       1004.2       8.0       8.0     15.9     17.0        Yes
# 12        994.3        993.0       8.0       8.0     17.4     15.8        Yes
# 13       1001.2       1001.8       NaN       7.0     15.8     19.8        Yes
# 14       1009.7       1008.7       NaN       NaN     15.9     23.5         No
#
#     RainTomorrow
# 0             No
# 1             No
# 2             No
# 3             No
# 4             No
# 5             No
# 6             No
# 7             No
# 8            Yes
# 9             No
# 10           Yes
# 11           Yes
# 12           Yes
# 13            No
# 14           NaN
#
# [15 rows x 23 columns]
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145445  2017-06-11    Uluru      2.4     19.1       0.0          NaN
# 145446  2017-06-12    Uluru      5.1     19.7       0.0          NaN
# 145447  2017-06-13    Uluru      2.5     21.2       0.0          NaN
# 145448  2017-06-14    Uluru      2.3     21.4       0.0          NaN
# 145449  2017-06-15    Uluru      2.6     22.5       0.0          NaN
# 145450  2017-06-16    Uluru      5.2     24.3       0.0          NaN
# 145451  2017-06-17    Uluru      6.4     23.4       0.0          NaN
# 145452  2017-06-18    Uluru      8.0     20.7       0.0          NaN
# 145453  2017-06-19    Uluru      7.4     20.6       0.0          NaN
# 145454  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145445       NaN           E           33.0         SE  ...        59.0
# 145446       NaN           E           46.0        ESE  ...        56.0
# 145447       NaN         ENE           35.0        ESE  ...        57.0
# 145448       NaN          SE           22.0         SE  ...        60.0
# 145449       NaN           S           19.0          S  ...        59.0
# 145450       NaN           E           24.0         SE  ...        53.0
# 145451       NaN         ESE           31.0          S  ...        53.0
# 145452       NaN         ESE           41.0         SE  ...        56.0
# 145453       NaN           E           35.0        ESE  ...        63.0
# 145454       NaN           E           31.0        ESE  ...        59.0
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 145445         24.0       1030.0       1026.2       NaN       NaN      8.0
# 145446         29.0       1028.5       1025.8       NaN       NaN      8.5
# 145447         32.0       1027.2       1023.0       NaN       NaN     10.3
# 145448         28.0       1026.9       1022.8       NaN       NaN      8.9
# 145449         24.0       1025.0       1021.4       NaN       NaN      8.8
# 145450         24.0       1023.8       1020.0       NaN       NaN     12.3
# 145451         25.0       1025.8       1023.0       NaN       NaN     11.2
# 145452         32.0       1028.1       1024.3       NaN       7.0     11.6
# 145453         33.0       1027.2       1023.3       NaN       NaN     11.0
# 145454         27.0       1024.7       1021.2       NaN       NaN      9.4
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 145445     18.8         No            No
# 145446     19.2         No            No
# 145447     20.3         No            No
# 145448     20.3         No            No
# 145449     22.1         No            No
# 145450     23.3         No            No
# 145451     23.1         No            No
# 145452     20.0         No            No
# 145453     20.3         No            No
# 145454     20.9         No            No
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [15 rows x 23 columns]

# %%
# Prieskum dat
# Ciel prace: musime zistit ci zajtra bude prsat alebo nie
# Ak je dany den 1mm (jeden kubicky milimeter na stvorcovy milimeter) alebo viac (stlpec 'rainfall') tak to znamena, ze zajtra
# bude prsat ak je menej tak nebude prsat (1mm dazd znamena, ze kazda plocha stvorcoveho metra je naplnena vodou s vyskou 1 mm)
# Zistime nasledovne: celkovy pocet dni, pocet dni s najmenej 1 mm alebo viac dazdom, pocet dni s menej ako 1 mm dazda a
# percento dni s dazdom 1mm alebo viac ako 1mm

# Zistime celkovy pocet dni
total_days = len(dataset)
print("Celkovy pocet dni: ", total_days)

# Zistime pocet dni s najmenej 1mm alebo viac dazda
total_at_least_1mm = dataset[dataset.Rainfall >= 1.0].count()[4]
print("Pocet dni s najmenej 1mm dazda: ", total_at_least_1mm)

# Zistime pocet dni s menej ako 1mm dazda
total_less_than_1mm = dataset[dataset.Rainfall < 1.0].count()[4]
print("Pocet dni s menej ako 1mm dazda: ", total_less_than_1mm)

# Zistime percento dni z dazdom 1mm a viac
# Pomocou uz zistenych pocet dni a pocet dni s najmenej ako 1mm dazda
percentage_rainy_days = (float(total_at_least_1mm)*100/float(total_days))
print("Percento dazdivych dni: ", percentage_rainy_days, "%")
# Out:
# Celkovy pocet dni:  145460
# Pocet dni s najmenej 1mm dazda:  33639
# Pocet dni s menej ako 1mm dazda:  108560
# Percento dazdivych dni:  23.12594527705211 %

# %%
# Percento nulovych hodnot v kazdom stlpci
dataset.isnull().mean()
# Out:
# Date             0.000000
# Location         0.000000
# MinTemp          0.010209
# MaxTemp          0.008669
# Rainfall         0.022419
# Evaporation      0.431665
# Sunshine         0.480098
# WindGustDir      0.070989
# WindGustSpeed    0.070555
# WindDir9am       0.072639
# WindDir3pm       0.029066
# WindSpeed9am     0.012148
# WindSpeed3pm     0.021050
# Humidity9am      0.018246
# Humidity3pm      0.030984
# Pressure9am      0.103568
# Pressure3pm      0.103314
# Cloud9am         0.384216
# Cloud3pm         0.408071
# Temp9am          0.012148
# Temp3pm          0.024811
# RainToday        0.022419
# RainTomorrow     0.022460
# dtype: float64

# %%
# Cistenie datasetu od prazdnych/null hodnot
# Na zaklade prestudovaneho datasetu sme zistili ze stlpce Evaporation, Sunshine, Cloud9am a Cloud3pm obsahuju viac ako 30% null
# hodnoty tak sme sa rozhodli ich odstranit
# Stlpec 'Location' tiez nepotrebujeme tak ho mozme odstranit
dataset = dataset.drop(['Evaporation','Sunshine','Cloud9am','Cloud3pm', 'Location'], axis=1)

# %%
# Skontrolujeme nazvy stlpcov
dataset.columns
# Out:
# Index(['Date', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Temp9am', 'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
# Zobrazime si dataset po jeho uprave
display(dataset.head(15)) # zobrazime si prvych 15 zaznamov z upraveneho datasetu
# Out:
#           Date  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0   2008-12-01     13.4     22.9       0.6           W           44.0
# 1   2008-12-02      7.4     25.1       0.0         WNW           44.0
# 2   2008-12-03     12.9     25.7       0.0         WSW           46.0
# 3   2008-12-04      9.2     28.0       0.0          NE           24.0
# 4   2008-12-05     17.5     32.3       1.0           W           41.0
# 5   2008-12-06     14.6     29.7       0.2         WNW           56.0
# 6   2008-12-07     14.3     25.0       0.0           W           50.0
# 7   2008-12-08      7.7     26.7       0.0           W           35.0
# 8   2008-12-09      9.7     31.9       0.0         NNW           80.0
# 9   2008-12-10     13.1     30.1       1.4           W           28.0
# 10  2008-12-11     13.4     30.4       0.0           N           30.0
# 11  2008-12-12     15.9     21.7       2.2         NNE           31.0
# 12  2008-12-13     15.9     18.6      15.6           W           61.0
# 13  2008-12-14     12.6     21.0       3.6          SW           44.0
# 14  2008-12-15      8.4     24.6       0.0         NaN            NaN
#
#    WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# 0           W        WNW          20.0          24.0         71.0
# 1         NNW        WSW           4.0          22.0         44.0
# 2           W        WSW          19.0          26.0         38.0
# 3          SE          E          11.0           9.0         45.0
# 4         ENE         NW           7.0          20.0         82.0
# 5           W          W          19.0          24.0         55.0
# 6          SW          W          20.0          24.0         49.0
# 7         SSE          W           6.0          17.0         48.0
# 8          SE         NW           7.0          28.0         42.0
# 9           S        SSE          15.0          11.0         58.0
# 10        SSE        ESE          17.0           6.0         48.0
# 11         NE        ENE          15.0          13.0         89.0
# 12        NNW        NNW          28.0          28.0         76.0
# 13          W        SSW          24.0          20.0         65.0
# 14          S        WNW           4.0          30.0         57.0
#
#     Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday  \
# 0          22.0       1007.7       1007.1     16.9     21.8        No
# 1          25.0       1010.6       1007.8     17.2     24.3        No
# 2          30.0       1007.6       1008.7     21.0     23.2        No
# 3          16.0       1017.6       1012.8     18.1     26.5        No
# 4          33.0       1010.8       1006.0     17.8     29.7        No
# 5          23.0       1009.2       1005.4     20.6     28.9        No
# 6          19.0       1009.6       1008.2     18.1     24.6        No
# 7          19.0       1013.4       1010.1     16.3     25.5        No
# 8           9.0       1008.9       1003.6     18.3     30.2        No
# 9          27.0       1007.0       1005.7     20.1     28.2       Yes
# 10         22.0       1011.8       1008.7     20.4     28.8        No
# 11         91.0       1010.5       1004.2     15.9     17.0       Yes
# 12         93.0        994.3        993.0     17.4     15.8       Yes
# 13         43.0       1001.2       1001.8     15.8     19.8       Yes
# 14         32.0       1009.7       1008.7     15.9     23.5        No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
# 5            No
# 6            No
# 7            No
# 8           Yes
# 9            No
# 10          Yes
# 11          Yes
# 12          Yes
# 13           No
# 14          NaN
